# %%
import os
#os.chdir('/Users/ros2/Documents/mpc_project/vehicle_dynamics')


import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from scipy import sparse
import vehicle_dynamics.vehicle_models as vm 
import mpc_controllers as mpc
import utils
import os
from scipy.ndimage import gaussian_filter1d
import path_planner as pf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       7 from matplotlib import animation
#       8 from scipy import sparse
# ----> 9 import vehicle_dynamics.vehicle_models as vm
#      10 import mpc_controllers as mpc
#      11 import utils
#
# ModuleNotFoundError: No module named 'vehicle_dynamics'

# %% [markdown]
# # Simple Path Definition

# %%
# Definition of sample path
x_ref = np.linspace(0, 120 * np.pi, 1200)
y_ref = np.sin(x_ref/40 * np.pi ) * 30 - np.sin(x_ref/20 * np.pi ) * 10

# Deffinition of the initial state
current_state = np.array([0., 2., np.pi/4, 10.0])


# Plot of the path
plt.plot(x_ref, y_ref, label='Path')
plt.plot(current_state[0], current_state[1], 'd', label='Initial position')
plt.title('Path')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Initialize MPC Controller and Path Follower

# %%
model_kin = vm.KinematicBicycleVariableSpeed('config_files/mpc_bicycle_velocity_config.yaml') 
n_horizon = 25
Q = sparse.diags([50, 50, 65, 60]) # State cost matrix
R = sparse.diags([5, 1]) # Input cost matrix

# Define the input constraints and State constraints (states unconstrained currently)
u_min_acc = -3
u_max_acc = 3
delta_min = -np.pi/6
delta_max = np.pi/6

InputConstraints = {'umin': [delta_min, u_min_acc], 
                    'umax': [delta_max, u_max_acc]}

StateConstraints = {'xmin': np.array([-np.inf, -np.inf, -np.inf, -np.inf]),
                    'xmax': np.array([np.inf, np.inf, np.inf, np.inf])}

# Define the MPC controller
mpc_controller = mpc.NMPCSolver(model=model_kin, N=n_horizon, Q=Q, R=R,
                             StateConstraints=StateConstraints,
                             InputConstraints=InputConstraints,
                             debug_plotting_callback=utils.plot_xref_evolution,
                             debug_plots_folder='debug_plots/') 

# Define the path follower
path_follower = pf.PathFollowerVariableSpeed({'x': x_ref, 'y': y_ref}, 0.05, mpc_controller, 0.05)
path_follower.populate_trajectory() # Populate the trajectory with the reference path and the velocity profile - Refer to README for more details
# Out:
# MPC Class initialized successfully

# %% [markdown]
# # Simulation

# %%
# INITIALIZE SIMULATION
state_history = [current_state]
input_history = []
j = path_follower.find_closest_index(current_state, path_follower.trajectory)

n_sim = 0
debug = False


# Initialize lists to store velocities
vehicle_velocities = []
reference_velocities = []
reference_curvatures = []

while n_sim < 500:
    debug = False
    if n_sim % 50 == 0:
        debug = False
        
    noise_std_devs = [0.2, 0.2, 0.1, 0.1]  # Different standard deviations for each component
    noise = np.array([np.random.normal(0, std_dev) for std_dev in noise_std_devs])
    disturbed_state = current_state + noise * 0
    optimal_input = path_follower.compute_optimal_input(disturbed_state, debug=debug)
    current_state = model_kin.step_nonlinear_model(current_state, optimal_input[0])  
    input_history.append(optimal_input[0])
    state_history.append(current_state)
    
    vehicle_velocities.append(current_state[3])

    # Find the closest index on the reference trajectory
    closest_index = path_follower.find_closest_index(current_state, path_follower.trajectory)

    # Record the reference velocity at the closest point
    reference_velocities.append(path_follower.trajectory['v'][closest_index])
    reference_curvatures.append(1/max(0.01, path_follower.trajectory['k'][closest_index]))
    
    # Plot fetched trajectory and input comparison
    if debug:
        path_follower.plot_fetched_trajectory_and_input(current_state, optimal_input, n_sim)
        input()
    
    n_sim += 1


# Prepare states for plotting
x_traj = [state_history[i][0] for i in range(n_sim)]
y_traj = [state_history[i][1] for i in range(n_sim)]
theta_traj = [state_history[i][2] for i in range(n_sim)]
v_traj = [state_history[i][3] for i in range(n_sim)]

# Prepare inputs for plotting
delta_input = [inp[0] for inp in input_history]
acc_input = [inp[1] for inp in input_history]
# Out:
# Execution time: 6 ms
# Average execution time after 1489 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1490 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1491 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1492 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1493 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1494 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1495 calls: 9 ms
# Execution time: 10 ms
# Average execution time after 1496 calls: 9 ms
# Execution time: 8 ms
# Average execution time after 1497 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1498 calls: 9 ms
# Execution time: 8 ms
# Average execution time after 1499 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1500 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1501 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1502 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1503 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1504 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1505 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1506 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1507 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1508 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1509 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1510 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1511 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1512 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1513 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1514 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1515 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1516 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1517 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1518 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1519 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1520 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1521 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1522 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1523 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1524 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1525 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1526 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1527 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1528 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1529 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1530 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1531 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1532 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1533 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1534 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1535 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1536 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1537 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1538 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1539 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1540 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1541 calls: 9 ms
# Execution time: 8 ms
# Average execution time after 1542 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1543 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1544 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1545 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1546 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1547 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1548 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1549 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1550 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1551 calls: 9 ms
# Execution time: 7 ms
# Average execution time after 1552 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1553 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1554 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1555 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1556 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1557 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1558 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1559 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1560 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1561 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1562 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1563 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1564 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1565 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1566 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1567 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1568 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1569 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1570 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1571 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1572 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1573 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1574 calls: 9 ms
# Execution time: 6 ms
# Average execution time after 1575 calls: 9 ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 31
#      28 vehicle_velocities.append(current_state[3])
#      30 # Find the closest index on the reference trajectory
# ---> 31 closest_index = path_follower.find_closest_index(current_state, path_follower.trajectory)
#      33 # Record the reference velocity at the closest point
#      34 reference_velocities.append(path_follower.trajectory['v'][closest_index])
#
# File ~/Documents/mpc_project/vehicle_dynamics/path_planner.py:90, in find_closest_index(current_state, trajectory, start_index, end_index)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 6))
plt.plot(vehicle_velocities, label='Vehicle Velocity', color='blue')
plt.plot(reference_velocities, label='Reference Velocity', color='green', linestyle='--')
plt.title("Vehicle Velocity vs Reference Velocity")
plt.xlabel("Simulation Step")
plt.ylabel("Velocity [m/s]")
plt.legend()
plt.grid(True)
plt.savefig('simulations/velocity_comparison.pdf')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.subplot(2, 1, 1)
plt.plot(delta_input, label='Steering Input', color='blue')
plt.plot([delta_min]*len(input_history), label='Minimum Steering', color='red', linestyle='dashdot')
plt.plot([delta_max]*len(input_history), label='Maximum Steering', color='red', linestyle='--') 
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(acc_input, label='Acceleration Input', color='green')
plt.plot([u_min_acc]*len(input_history), label='Minimum Accel', color='red', linestyle='dashdot')
plt.plot([u_max_acc]*len(input_history), label='Maximum Accel', color='red', linestyle='--')
plt.savefig('simulations/input_comparison.pdf')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x_ref[:n_sim], y_ref[:n_sim], color='blue', label='reference')
line, = ax.plot([], [], color='orange', label='trajectory')

def init():
    line.set_data([], [])
    return line,

def update(frame):
    line.set_data(x_traj[:frame], y_traj[:frame])
    return line,

ani = animation.FuncAnimation(fig, update, frames=n_sim, init_func=init, blit=True)
ani.save('simulations/trajectory_animation.gif', writer='imagemagick')
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
